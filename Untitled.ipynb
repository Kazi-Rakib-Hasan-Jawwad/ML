# %%
import pandas as pd
import pylab as pl
import numpy as np
import scipy.optimize as opt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
S1_train_df = pd.read_csv(r"C:\Users\USER\Desktop\New folder (4)\Sleep Case I\train_case1.csv")
S1_test_df = pd.read_csv(r"C:\Users\USER\Desktop\New folder (4)\Sleep Case I\test_case1.csv")

# %%
S1_train_df.describe()
S1_test_df.describe()
# Out:
#           -0.10883      0.10157      0.48028    -0.035221       0.0481  \
# count  4979.000000  4979.000000  4979.000000  4979.000000  4979.000000
# mean     -0.001456     0.000463    -0.003049    -0.008333     0.007393
# std       0.722281     0.907808     0.549269     0.077036     0.983479
# min      -0.391040    -1.300000    -0.460910    -0.072249    -1.444100
# 25%      -0.314725    -0.680980    -0.266715    -0.047173    -0.668080
# 50%      -0.215450    -0.243480    -0.152890    -0.033634    -0.267020
# 75%       0.009268     0.487500     0.031688    -0.001210     0.333130
# max      17.024000     7.887300     4.328100     1.026400    10.278000
#
#            0.28769       1.2204     -0.26475     -0.71967     0.042129  ...  \
# count  4979.000000  4979.000000  4979.000000  4979.000000  4979.000000  ...
# mean      0.000458     0.004504    -0.003401     0.001982    -0.002757  ...
# std       1.000345     0.972538     0.765384     1.008357     0.707366  ...
# ...

# %%
S1_train_df.head(100)
# Out:
#     -0.31715  -0.53474  -0.0058913   0.01438   -0.6805  -0.51243   0.21222  \
# 0  -0.274150 -0.239160    0.629480  0.036312 -0.483710 -0.110720  1.473000
# 1  -0.220840  0.552730   -0.032749 -0.039886 -0.285210  0.746580  0.143290
# 2  -0.324040 -0.795700   -0.259170 -0.029691 -0.716940 -0.938630 -0.556510
# 3  -0.332040 -0.946810   -0.297580 -0.058373 -0.761740 -1.238500 -0.710020
# 4  -0.144480  1.071700   -0.113210 -0.018583 -0.049345  1.209600 -0.077313
# 5  -0.212050  0.158950   -0.177610 -0.033659 -0.255810  0.349790 -0.273060
# 6  -0.177200 -0.071506   -0.120220  0.022346 -0.145110  0.092233 -0.097678
# 7  -0.318010 -0.882240   -0.326350 -0.048890 -0.684960 -1.103800 -0.837300
# 8  -0.335890 -0.678930    0.080730 -0.044450 -0.784430 -0.736880  0.421660
# 9   0.314790  3.626100    0.504620  0.113220  0.915860  2.968500  1.262900
# 10 -0.098319 -0.036782   -0.272540 -0.052758  0.075607  0.132500 -0.608140
# ...

# %%
S1_train_FR_df = pd.read_csv(r"C:\Users\USER\Desktop\New folder (4)\Sleep Case I\train_case1_FR_v1.csv")
S1_test_FR_df = pd.read_csv(r"C:\Users\USER\Desktop\New folder (4)\Sleep Case I\test_case1_FR_v1.csv")

# %%
S1_train_FR_df.head()
# Out:
#       Feat1     Feat2     Feat3     Feat4     Feat5  outcome
# 0 -0.053862  0.091337 -0.045134  0.005509  0.042472        5
# 1 -0.039098  0.081333 -0.053083 -0.002254  0.029283        5
# 2  0.043648  0.038231  0.084861  0.010920  0.014392        2
# 3  0.109580  0.023705  0.009215  0.021872 -0.040083        2
# 4 -0.133690  0.071284  0.092952  0.018672  0.016968        5

# %%
X = np.asarray(S1_train_FR_df[['Feat1', 'Feat2', 'Feat3', 'Feat4', 'Feat5']])
X[0:10]
# Out:
# array([[-0.053862 ,  0.091337 , -0.045134 ,  0.0055092,  0.042472 ],
#        [-0.039098 ,  0.081333 , -0.053083 , -0.0022543,  0.029283 ],
#        [ 0.043648 ,  0.038231 ,  0.084861 ,  0.01092  ,  0.014392 ],
#        [ 0.10958  ,  0.023705 ,  0.0092149,  0.021872 , -0.040083 ],
#        [-0.13369  ,  0.071284 ,  0.092952 ,  0.018672 ,  0.016968 ],
#        [ 0.055584 ,  0.0047668,  0.024109 ,  0.029138 ,  0.013707 ],
#        [ 0.065721 , -0.026021 ,  0.039896 ,  0.030164 ,  0.0051072],
#        [ 0.2064   , -0.013014 , -0.061931 ,  0.032458 , -0.041826 ],
#        [-0.079868 ,  0.082061 ,  0.044803 ,  0.0088511,  0.057857 ],
#        [-0.071247 ,  0.090088 , -0.016852 , -0.0077479,  0.0056532]])

# %%
Y = np.asarray(S1_train_FR_df[['outcome']])
Y[0:10]
# Out:
# array([[5],
#        [5],
#        [2],
#        [2],
#        [5],
#        [2],
#        [2],
#        [2],
#        [5],
#        [6]], dtype=int64)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
LR = LogisticRegression(C=0.01, solver='liblinear').fit(X,Y)
LR
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\USER\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=0.01, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='liblinear',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
y_test=
